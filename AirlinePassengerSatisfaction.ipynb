# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Reading Dataset

# %%
data = pd.read_csv("airline-dataset.csv")
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data.shape
# Out:
# (103904, 25)

# %%
data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# ###### The collection contains roughly 100K passenger entry records.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# ###### Since the first two columns won't be useful for factor analysis, we may remove them.

# %%
data = data.drop(data.iloc[:,[0, 1]], axis = 1)

# %%
cat_indexes = [0, 1, 3, 4] + list(range(6, 20))
data.iloc[:,cat_indexes] = data.iloc[:,cat_indexes].astype('category')

# %%
data.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %% [markdown]
# ###### Arrival Delay in Minutes contains about 310 Null values.

# %%
#there are null values in the 'Arrival Delay in Minutes'
# meadian is used to fill those 
data['Arrival Delay in Minutes'].fillna(data['Arrival Delay in Minutes'].median(axis = 0), inplace = True)
#check the null and get the sum
data.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# ###### The column's median was used to fill in the missing data. Dataset is currently NULL-free.

# %% [markdown]
# # Data Visualization

# %%
"""
    For each category characteristic, the total number of values, 
    the number of distinct values, the most common element and the 
    total number of such items are provided.
"""
data.describe(include = ['category'])
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   103904          103904           103904    103904
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     52727           84923            71655     49665
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# count                  103904                             103904
# unique                      6                                  6
# top                         3                                  4
# freq                    25868                              25546
#
#         Ease of Online booking  Gate location  Food and drink  \
# count                   103904         103904          103904
# unique                       6              6               6
# top                          3              3               4
# freq                     24449          28577           24359
#
# ...

# %%
#Distribution of the target values
plt.pie(data.satisfaction.value_counts(), labels = ["Neutral or dissatisfied", "Satisfied"] , autopct = '%1.1f%%')
pass

# %% [markdown]
# ### Non-Categorical Data

# %%
#The reason for linear dependence between the two variables is because if a flight departs late then it will arrive late at destination.
plt.scatter(data['Arrival Delay in Minutes'], data['Departure Delay in Minutes'], alpha = 0.5 , color = 'green')

# %%
#use plt figure to display
plt.figure(figsize=(20, 10))

data['Age'].hist(bins=50)

#set title 
plt.title("Passengers' age range", weight="bold", size="20", color='red')
#set X axis
plt.xlabel("Group of Age", size="15", color='green')
#set Y axis
plt.ylabel("Passengers", size="15", color='orange')
# Out:
# Text(0, 0.5, 'Passengers')

# %% [markdown]
# ### Categorical Data

# %%
category = data.iloc[:,cat_indexes]
fig, axes = plt.subplots(6, 3, figsize = (20, 20))
for x, col in enumerate(category):
    col_values = data[col].value_counts()
    labels = col_values.index
    sizes = col_values.values
    axes[x//3, x%3].pie(sizes, labels = labels , autopct = '%1.0f%%', startangle = 90)
    axes[x//3, x%3].axis('equal')
    axes[x//3, x%3].set_title(col)
plt.show()

# %% [markdown]
# ## One Hot Encoding

# %%
# Import label encoder
from sklearn import preprocessing

# The object label_encoder is capable of comprehending word labels.
lbEncoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['Gender']= lbEncoder.fit_transform(data['Gender'])
data['Customer Type']= lbEncoder.fit_transform(data['Customer Type'])
data['Type of Travel']= lbEncoder.fit_transform(data['Type of Travel'])
data['Class']= lbEncoder.fit_transform(data['Class'])
data['satisfaction']= lbEncoder.fit_transform(data['satisfaction'])

# %% [markdown]
# # Split Train Test

# %%
#import model selection from sklearn
from sklearn.model_selection import train_test_split

#drop columns
X = data.drop(columns=['Gender','Departure Delay in Minutes','Arrival Delay in Minutes','satisfaction','Gate location'])
#output variable
y = data['satisfaction']
  
# using the train test split function
X_train, X_test, y_train, y_test = train_test_split(X,y ,random_state=3, test_size=0.2 )

X.head(5)
# Out:
#    Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0              0   13               1      2              460
# 1              1   25               0      0              235
# 2              0   26               0      0             1142
# 3              0   25               0      0              562
# 4              0   61               0      0              214
#
#   Inflight wifi service Departure/Arrival time convenient  \
# 0                     3                                 4
# 1                     3                                 2
# 2                     2                                 2
# 3                     2                                 5
# 4                     3                                 3
#
#   Ease of Online booking Food and drink Online boarding Seat comfort  \
# 0                      3              5               3            5
# 1                      3              1               3            1
# ...

# %% [markdown]
# ## Decision Tree Classifier

# %%
#import metrics from sklearn
from sklearn import metrics
#import decision tree from sklearn
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
y_pred1 = tree.predict(X_test)
accuracy1 = metrics.accuracy_score(y_test, y_pred1)

#The precision score is a useful measure of the success of prediction when the classes are very imbalanced.
precision1 = metrics.precision_score(y_test, y_pred1)

print("accuracy score :",accuracy1)
print("precision score:",precision1)
# Out:
# accuracy score : 0.9450459554400654
# precision score: 0.9355162044771133

# %% [markdown]
# ## Logistic Regression

# %%
#import ensemble form sklearn
from sklearn.linear_model import LogisticRegression

regression = LogisticRegression()
regression.fit(X_train, y_train)
y_pred2 = regression.predict(X_test)
accuracy2 = metrics.accuracy_score(y_test, y_pred2)

#The precision score is a useful measure of the success of prediction when the classes are very imbalanced.
precision2 = metrics.precision_score(y_test, y_pred2)
print("accuracy:",accuracy2)
print("precision:",precision2)

# %% [markdown]
# ## Random Forest

# %%
#import ensemble form sklearn 
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier()
forest.fit(X_train, y_train)
y_pred3 = forest.predict(X_test)
accuracy3 = metrics.accuracy_score(y_test, y_pred3)

#The precision score is a useful measure of the success of prediction when the classes are very imbalanced.
precision3 = metrics.precision_score(y_test, y_pred3)
print("accuracy score :",accuracy3)
print("precision score:",precision3)
# Out:
# accuracy score : 0.9628988017900967
# precision score: 0.9745134383688601

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred4 = svc.predict(X_test)
accuracy4 = metrics.accuracy_score(y_test, y_pred4)

#The precision score is a useful measure of the success of prediction when the classes are very imbalanced.
precision4 = metrics.precision_score(y_test, y_pred4)
print("accuracy:",accuracy4)
print("precision:",precision4)
